# %%
from gpu_utils import create_sorted_weights_for_matmul, fitness_nonlamarckian
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [2], in <cell line: 1>()
# ----> 1 from gpu_utils import create_sorted_weights_for_matmul, fitness_nonlamarckian
#
# ImportError: cannot import name 'create_sorted_weights_for_matmul' from 'gpu_utils' (/home/mmatak/fuine/gpu_utils/__init__.py)
