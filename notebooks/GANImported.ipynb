# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data
from torch.utils.data import TensorDataset
import numpy as np

from src.gan.generator import Generator
from src.gan.discriminator import Discriminator

from src.data_loaders.datasets.fashion_mnist_dataset import FashionMNISTDataset
from src.data_loaders.datasets.generated_fake_dataset import GeneratedFakeDataset
from src.data_loaders.datasource import show_images_from_tensor

# %%
device = torch.device("cuda:0")

# %%
#models
latent_dim = 32
generator = Generator(latent_dim=latent_dim, hidden_dim=256, output_dim=784).to(device)
discriminator = Discriminator(hidden_dim=256, input_dim=784).to(device)

# %%
fashionMNIST = FashionMNISTDataset()
train_data_real = fashionMNIST.train_data

generated_fake_dataset = GeneratedFakeDataset(generator, len(train_data_real))
train_data_fake = generated_fake_dataset.train_dataset

train_data_merged = torch.cat([train_data_real, train_data_fake], 0)

# %%
train_targets_real = fashionMNIST.get_train_set_targets()

train_targets_fake = generated_fake_dataset.get_train_set_targets()

train_targets_merged = torch.cat([train_targets_real, train_targets_fake], 0).unsqueeze(1)

# %%
discriminator_optimizer = torch.optim.Adam(discriminator.parameters(), lr=0.0001)
discriminator_scheduler = optim.lr_scheduler.ExponentialLR(optimizer=discriminator_optimizer, gamma=0.99)
criterion = nn.MSELoss()

# %%
train_loader = data.DataLoader(TensorDataset(train_data_merged, train_targets_merged), batch_size=256, shuffle=True, drop_last=True, pin_memory=True, num_workers=4)

# %%
def show_sample_predictions(discriminator, my_data_loader_batch):
    show_images_from_tensor(my_data_loader_batch[0].cpu())
    predictions = discriminator(my_data_loader_batch[0].to(device)).cpu()
    print(predictions)
    print(f"Loss: {criterion(predictions.cuda(), my_data_loader_batch[1].cuda())}")

# %%
show_sample_predictions(discriminator, next(iter(train_loader)))
# Out:
# tensor([[0.1143],
#         [0.1287],
#         [0.0437],
#         [0.1407],
#         [0.0859],
#         [0.1394],
#         [0.1404],
#         [0.1393],
#         [0.1286],
#         [0.1372],
#         [0.1387],
#         [0.1391],
#         [0.0767],
#         [0.1422],
#         [0.0839],
#         [0.0880],
#         [0.0934],
#         [0.1015],
#         [0.0752],
#         [0.1384],
#         [0.0810],
#         [0.1045],
#         [0.1369],
#         [0.1396],
#         [0.0468],
#         [0.0675],
#         [0.1371],
#         [0.1406],
#         [0.1377],
#         [0.1393],
#         [0.1274],
#         [0.0743],
#         [0.1360],
#         [0.1135],
#         [0.1402],
#         [0.1064],
#         [0.1400],
#         [0.1172],
#         [0.1360],
#         [0.0938],
#         [0.1387],
#         [0.1363],
#         [0.0496],
#         [0.0657],
#         [0.1385],
#         [0.1368],
#         [0.1419],
#         [0.1403],
#         [0.1387],
#         [0.0550],
#         [0.0740],
#         [0.1557],
#         [0.1378],
#         [0.1135],
#         [0.1380],
#         [0.0751],
#         [0.1371],
#         [0.1376],
#         [0.0806],
#         [0.1320],
#         [0.1136],
#         [0.1075],
#         [0.1816],
#         [0.1379],
#         [0.0803],
#         [0.1425],
#         [0.1385],
#         [0.0901],
#         [0.0929],
#         [0.1143],
#         [0.1368],
#         [0.1150],
#         [0.0838],
#         [0.1387],
#         [0.1418],
#         [0.1376],
#         [0.0760],
#         [0.1376],
#         [0.1096],
#         [0.0483],
#         [0.0899],
#         [0.1116],
#         [0.1373],
#         [0.1380],
#         [0.1401],
#         [0.0769],
#         [0.1394],
#         [0.1395],
#         [0.0714],
#         [0.0725],
#         [0.0801],
#         [0.1003],
#         [0.0645],
#         [0.1365],
#         [0.0959],
#         [0.1435],
#         [0.1390],
#         [0.1380],
#         [0.0494],
#         [0.0961],
#         [0.0929],
#         [0.0418],
#         [0.1075],
#         [0.0870],
#         [0.1391],
#         [0.1377],
#         [0.1122],
#         [0.1413],
#         [0.0974],
#         [0.1399],
#         [0.0597],
#         [0.1265],
#         [0.0782],
#         [0.1363],
#         [0.0388],
#         [0.0785],
#         [0.0827],
#         [0.1314],
#         [0.0856],
#         [0.1375],
#         [0.1387],
#         [0.0594],
#         [0.1414],
#         [0.1398],
#         [0.1368],
#         [0.0980],
#         [0.1366],
#         [0.0650],
#         [0.0716],
#         [0.0767],
#         [0.0461],
#         [0.0917],
#         [0.1390],
#         [0.1016],
#         [0.1410],
#         [0.1355],
#         [0.1358],
#         [0.1387],
#         [0.1169],
#         [0.1384],
#         [0.1195],
#         [0.1426],
#         [0.1001],
#         [0.0984],
#         [0.0983],
#         [0.1176],
#         [0.1413],
#         [0.1381],
#         [0.1367],
#         [0.1116],
#         [0.1140],
#         [0.1402],
#         [0.1503],
#         [0.0886],
#         [0.0799],
#         [0.0617],
#         [0.0908],
#         [0.0886],
#         [0.1375],
#         [0.0720],
#         [0.1406],
#         [0.0691],
#         [0.1413],
#         [0.1396],
#         [0.1407],
#         [0.1377],
#         [0.1208],
#         [0.1427],
#         [0.1409],
#         [0.0952],
#         [0.1399],
#         [0.1390],
#         [0.1613],
#         [0.0929],
#         [0.1059],
#         [0.1394],
#         [0.1394],
#         [0.1362],
#         [0.0544],
#         [0.1425],
#         [0.1387],
#         [0.1377],
#         [0.1398],
#         [0.1416],
#         [0.0540],
#         [0.1382],
#         [0.1405],
#         [0.1345],
#         [0.1394],
#         [0.0974],
#         [0.1386],
#         [0.1172],
#         [0.0786],
#         [0.1363],
#         [0.1391],
#         [0.1387],
#         [0.0758],
#         [0.1406],
#         [0.1386],
#         [0.0616],
#         [0.0824],
#         [0.1406],
#         [0.0819],
#         [0.0939],
#         [0.1372],
#         [0.1474],
#         [0.1392],
#         [0.0848],
#         [0.0760],
#         [0.0899],
#         [0.0978],
#         [0.1375],
#         [0.0647],
#         [0.0657],
#         [0.1385],
#         [0.1363],
#         [0.1336],
#         [0.0617],
#         [0.0418],
#         [0.0751],
#         [0.1404],
#         [0.0936],
#         [0.1378],
#         [0.0898],
#         [0.1174],
#         [0.0715],
#         [0.1412],
#         [0.1404],
#         [0.1389],
#         [0.1388],
#         [0.1369],
#         [0.0995],
#         [0.1388],
#         [0.1106],
#         [0.1278],
#         [0.1124],
#         [0.0883],
#         [0.1560],
#         [0.1124],
#         [0.0660],
#         [0.1396],
#         [0.1411],
#         [0.1677],
#         [0.1379],
#         [0.1349],
#         [0.0820],
#         [0.1392],
#         [0.1377],
#         [0.1414],
#         [0.0470],
#         [0.0933],
#         [0.1351],
#         [0.1402],
#         [0.1403],
#         [0.1378],
#         [0.1391]], grad_fn=<ToCopyBackward0>)
# Loss: 0.4407922029495239

# %%
num_epochs = 100
for epoch in range(num_epochs):
    # For each batch in the dataloader
    discriminator_acc = []
    for i, data in enumerate(train_loader, 0):

        ############################
        # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
        ###########################
        ## Train with all-real batch
        discriminator_optimizer.zero_grad()
        # Format batch
        images = data[0].to(device)
        b_size = images.size(0)
        label = torch.ones((b_size,), dtype=torch.float, device=device) # Setting labels for real images
        # Forward pass real batch through D
        output = discriminator(images).view(-1)
        # Calculate loss on all-real batch
        error_discriminator = criterion(output, label)
        # Calculate gradients for D in backward pass
        error_discriminator.backward()
        discriminator_acc.append(output.mean().item())
        # Update D
        discriminator_optimizer.step()
    print(f"Epoch: {epoch}, discriminator error: {np.mean(discriminator_acc):.3}")
# Out:
# Epoch: 0, discriminator error: 0.959
# Epoch: 1, discriminator error: 0.994
# Epoch: 2, discriminator error: 0.999
# Epoch: 3, discriminator error: 1.0
# Epoch: 4, discriminator error: 1.0
# Epoch: 5, discriminator error: 1.0
# Epoch: 6, discriminator error: 1.0
# Epoch: 7, discriminator error: 1.0
# Epoch: 8, discriminator error: 1.0
# Epoch: 9, discriminator error: 1.0
# Epoch: 10, discriminator error: 1.0
# Epoch: 11, discriminator error: 1.0
# Epoch: 12, discriminator error: 1.0
# Epoch: 13, discriminator error: 1.0
# Epoch: 14, discriminator error: 1.0
# Epoch: 15, discriminator error: 1.0
# Epoch: 16, discriminator error: 1.0
# Epoch: 17, discriminator error: 1.0
# Epoch: 18, discriminator error: 1.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [34], line 5
#       2 for epoch in range(num_epochs):
#       3     # For each batch in the dataloader
#       4     discriminator_acc = []
# ----> 5     for i, data in enumerate(train_loader, 0):
#       6
#       7         ############################
#       8         # (1) Update D network: maximize log(D(x)) + log(1 - D(G(z)))
#       9         ###########################
#      10         ## Train with all-real batch
#      11         discriminator_optimizer.zero_grad()
#      12         # Format batch
#
# File C:\inz\nDES-thesis\venv\lib\site-packages\torch\utils\data\dataloader.py:681, in _BaseDataLoaderIter.__next__(self)
#     678 if self._sampler_iter is None:
#     679     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     680     self._reset()  # type: ignore[call-arg]
# --> 681 data = self._next_data()
#     682 self._num_yielded += 1
#     683 if self._dataset_kind == _DatasetKind.Iterable and \
#     684         self._IterableDataset_len_called is not None and \
#     685         self._num_yielded > self._IterableDataset_len_called:
#
# File C:\inz\nDES-thesis\venv\lib\site-packages\torch\utils\data\dataloader.py:1359, in _MultiProcessingDataLoaderIter._next_data(self)
#    1356     return self._process_data(data)
#    1358 assert not self._shutdown and self._tasks_outstanding > 0
# -> 1359 idx, data = self._get_data()
#    1360 self._tasks_outstanding -= 1
#    1361 if self._dataset_kind == _DatasetKind.Iterable:
#    1362     # Check for _IterableDatasetStopIteration
#
# File C:\inz\nDES-thesis\venv\lib\site-packages\torch\utils\data\dataloader.py:1315, in _MultiProcessingDataLoaderIter._get_data(self)
#    1313 elif self._pin_memory:
#    1314     while self._pin_memory_thread.is_alive():
# -> 1315         success, data = self._try_get_data()
#    1316         if success:
#    1317             return data
#
# File C:\inz\nDES-thesis\venv\lib\site-packages\torch\utils\data\dataloader.py:1163, in _MultiProcessingDataLoaderIter._try_get_data(self, timeout)
#    1150 def _try_get_data(self, timeout=_utils.MP_STATUS_CHECK_INTERVAL):
#    1151     # Tries to fetch data from `self._data_queue` once for a given timeout.
#    1152     # This can also be used as inner loop of fetching without timeout, with
#    (...)
#    1160     # Returns a 2-tuple:
#    1161     #   (bool: whether successfully get data, any: data if successful else None)
#    1162     try:
# -> 1163         data = self._data_queue.get(timeout=timeout)
#    1164         return (True, data)
#    1165     except Exception as e:
#    1166         # At timeout and error, we manually check whether any worker has
#    1167         # failed. Note that this is the only mechanism for Windows to detect
#    1168         # worker failures.
#
# File ~\AppData\Local\Programs\Python\Python310\lib\queue.py:180, in Queue.get(self, block, timeout)
#     178         if remaining <= 0.0:
#     179             raise Empty
# --> 180         self.not_empty.wait(remaining)
#     181 item = self._get()
#     182 self.not_full.notify()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
show_sample_predictions(discriminator, next(iter(train_loader)))

# %% [markdown]
# # Wniosek -> dyskriminator się nie uczy nawet na zwykłym gradiencie
